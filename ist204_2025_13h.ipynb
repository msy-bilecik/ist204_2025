# %% [markdown]
# <a href="https://colab.research.google.com/github/msy-bilecik/ist204_2025/blob/main/ist204_2025_13h.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]},
index = [1, 2, 3])

print(df)
display(df)
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['a'].plot(kind='hist', bins=20, title='a')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['b'].plot(kind='hist', bins=20, title='b')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['c'].plot(kind='hist', bins=20, title='c')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='a', y='b', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df2 = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]],
index=[1, 2, 3],
columns=['a', 'b', 'c'])

display(df)
display(df2)
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df3 = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]},
index = pd.MultiIndex.from_tuples([('d',1),('d',2),('e',2)],names=['n','v']))
display(df3)
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
dftitatic=pd.read_excel("https://hbiostat.org/data/repo/titanic3.xls")

# %%
display(dftitatic)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
dfX=pd.melt(dftitatic)
display(dfX)
# Out:
#         variable value
# 0         pclass     1
# 1         pclass     1
# 2         pclass     1
# 3         pclass     1
# 4         pclass     1
# ...          ...   ...
# 18321  home.dest   NaN
# 18322  home.dest   NaN
# 18323  home.dest   NaN
# 18324  home.dest   NaN
# 18325  home.dest   NaN
#
# [18326 rows x 2 columns]

# %%
dfY=pd.concat([dftitatic,dftinatic],ignore_index=True)
display(dfY.sort_index())
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 2613       3         0                             Zabour, Miss. Hileni
# 2614       3         0                            Zabour, Miss. Thamine
# 2615       3         0                        Zakarian, Mr. Mapriededer
# 2616       3         0                              Zakarian, Mr. Ortin
# 2617       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
display(dftitatic.sort_values(by="age",ascending=True))
# Out:
#       pclass  survived                                     name     sex  \
# 763        3         1  Dean, Miss. Elizabeth Gladys "Millvina"  female
# 747        3         0  Danbom, Master. Gilbert Sigvard Emanuel    male
# 1240       3         1          Thomas, Master. Assad Alexander    male
# 427        2         1                Hamalainen, Master. Viljo    male
# 658        3         1            Baclini, Miss. Helene Barbara  female
# ...      ...       ...                                      ...     ...
# 1293       3         0        Williams, Mr. Howard Hugh "Harry"    male
# 1297       3         0                   Wiseman, Mr. Phillippe    male
# 1302       3         0                        Yousif, Mr. Wazli    male
# 1303       3         0                    Yousseff, Mr. Gerious    male
# 1305       3         0                    Zabour, Miss. Thamine  female
#
#          age  sibsp  parch      ticket     fare cabin embarked boat  body  \
# ...

# %%
dftitatic.drop(columns=['sibsp','parch'])
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  ticket      fare    cabin embarked boat   body  \
# ...

# %%
display(dftitatic)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
dftitatic.iloc[10:20]
# Out:
#     pclass  survived                                               name  \
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
# 19       1         0                               Beattie, Mr. Thomson
#
#        sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 10    male  47.0      1      0  PC 17757  227.5250  C62 C64        C  NaN
# ...

# %%
dfTT=dftitatic[['name','sex','age','cabin']]
display(dfTT)
display(dfTT.name)
# Out:
#                                                  name     sex      age  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000
# 1                      Allison, Master. Hudson Trevor    male   0.9167
# 2                        Allison, Miss. Helen Loraine  female   2.0000
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# ...                                               ...     ...      ...
# 1304                             Zabour, Miss. Hileni  female  14.5000
# 1305                            Zabour, Miss. Thamine  female      NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000
# 1307                              Zakarian, Mr. Ortin    male  27.0000
# 1308                               Zimmerman, Mr. Leo    male  29.0000
#
#         cabin
# 0          B5
# 1     C22 C26
# 2     C22 C26
# 3     C22 C26
# 4     C22 C26
# ...       ...
# ...

# %%
dftitatic.loc[:,'name':'embarked']
# Out:
#                                                  name     sex      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...                                               ...     ...      ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.5000      1
# 1305                            Zabour, Miss. Thamine  female      NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000      0
# 1307                              Zakarian, Mr. Ortin    male  27.0000      0
# 1308                               Zimmerman, Mr. Leo    male  29.0000      0
#
# ...

# %%
dftitatic.loc[dftitatic.age<10,['name','age']].reset_index(drop=True)
# Out:
#                                name     age
# 0    Allison, Master. Hudson Trevor  0.9167
# 1      Allison, Miss. Helen Loraine  2.0000
# 2         Dodge, Master. Washington  4.0000
# 3   Spedden, Master. Robert Douglas  6.0000
# 4         Becker, Master. Richard F  1.0000
# ..                              ...     ...
# 77    Skoog, Miss. Margit Elizabeth  2.0000
# 78       Strom, Miss. Telma Matilda  2.0000
# 79  Thomas, Master. Assad Alexander  0.4167
# 80   Touma, Master. Georges Youssef  7.0000
# 81       Touma, Miss. Maria Youssef  9.0000
#
# [82 rows x 2 columns]

# %%
len(dftitatic)
# Out:
# 1309

# %%
dftitatic['cabin'].value_counts()
# Out:
# cabin
# C23 C25 C27        6
# B57 B59 B63 B66    5
# G6                 5
# D                  4
# F4                 4
#                   ..
# F E46              1
# F E57              1
# F E69              1
# E10                1
# F38                1
# Name: count, Length: 186, dtype: int64

# %%
dftitatic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
dftitatic.hist()
# Out:
# array([[<Axes: title={'center': 'pclass'}>,
#         <Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'sibsp'}>,
#         <Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>],
#        [<Axes: title={'center': 'body'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
dftitatic.plot.scatter(y='age',x="parch")
# Out:
# <Axes: xlabel='parch', ylabel='age'>

# %%
dfff=dftitatic.groupby(['cabin']).mean()
display(dfff)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})
df.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
dftitatic.size
# Out:
# 18326

# %% [markdown]
# ## örnek

# %%
dfI=pd.read_excel("isgucu.xls")

# %%
dfI2=dfI.iloc[4:].drop(columns=["Unnamed: 4"]).reset_index(drop=True)
display(dfI2)

dfIErkek=dfI2.iloc[]
# Out:
#                  Temel işgücü göstergeleri, Mart 2025  \
# 0                                                 NaN
# 1                                      Toplam - Total
# 2   15 ve daha yukarı yaştaki nüfus\nPopulation 15...
# 3                                İşgücü\nLabour force
# 4                                İstihdam\nEmployment
# 5                                 İşsiz\nUnemployment
# 6   İşgücüne dahil olmayanlar         \nNot in lab...
# 7   İşgücüne katılma oranı (%)\nLabour force parti...
# 8             İstihdam oranı (%)\nEmployment rate (%)
# 9           İşsizlik oranı (%)\nUnemployment rate (%)
# 10                                       Erkek - Male
# 11  15 ve daha yukarı yaştaki nüfus\nPopulation 15...
# 12                               İşgücü\nLabour force
# 13                               İstihdam\nEmployment
# 14                                İşsiz\nUnemployment
# 15  İşgücüne dahil olmayanlar         \nNot in lab...
# ...

# %%
dftitatic.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
dftitatic.plot.scatter(x='age',y='sibsp')
# Out:
# <Axes: xlabel='age', ylabel='sibsp'>
